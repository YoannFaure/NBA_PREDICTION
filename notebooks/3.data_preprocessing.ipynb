# %% [markdown]
# # Package & data

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
data_nba = pd.read_csv("../data/processed/nba_data.csv")
data_nba.head()
# Out:
#    PLAYER_ID PLAYER_NAME PLAYER_POS  PLAYER_YEAR_START  PLAYER_GAME_AGE  \
# 0        100  Tim Legler         SG               1990               32
# 1        100  Tim Legler         SG               1990               32
# 2        100  Tim Legler         SG               1990               32
# 3        100  Tim Legler         SG               1990               32
# 4        100  Tim Legler         SG               1990               32
#
#    PLAYER_HEIGHT  PLAYER_WEIGHT  PLAYER_BORN_YEAR  PLAYER_EXP   GAME_ID  ...  \
# 0            193             90              1966           8  29700427  ...
# 1            193             90              1966           8  29700427  ...
# 2            193             90              1966           8  29700427  ...
# 3            193             90              1966           8  29700427  ...
# 4            193             90              1966           8  29700427  ...
#
#    SHOT_ACTION_TYPE  SHOT_ACTION_CATEGORY       SHOT_TYPE  \
# 0         Jump Shot             Jump Shot  2PT Field Goal
# 1         Jump Shot             Jump Shot  2PT Field Goal
# 2         Jump Shot             Jump Shot  2PT Field Goal
# 3         Jump Shot             Jump Shot  2PT Field Goal
# 4         Jump Shot             Jump Shot  2PT Field Goal
#
#          SHOT_ZONE_BASIC  SHOT_ZONE_AREA  SHOT_ZONE_RANGE SHOT_DISTANCE  \
# 0              Mid-Range   Right Side(R)         8-16 ft.            15
# 1              Mid-Range   Right Side(R)         8-16 ft.            14
# 2              Mid-Range    Left Side(L)         8-16 ft.            10
# 3  In The Paint (Non-RA)       Center(C)  Less Than 8 ft.             5
# 4              Mid-Range   Right Side(R)         8-16 ft.            14
#
#   SHOT_X_LOCATION  SHOT_Y_LOCATION  SHOT_MADE_FLAG
# 0             117              109               1
# 1             143               25               0
# 2             -87               55               0
# 3              -1               53               0
# 4              89              113               0
#
# [5 rows x 30 columns]

# %% [markdown]
# # Preprocessing

# %%
data = data_nba

# columns dic
columns_to_drop = [
    'PLAYER_ID',
    'PLAYER_NAME',
    'GAME_ID', 
    'GAME_EVENT_ID', 
    'GAME_YEAR', 
    'GAME_DATE',
    'GAME_SEASON_TYPE', 
    'GAME_TEAM_ID', 
    'GAME_TEAM_NAME', 
    'GAME_HOME_TEAM',
    'GAME_AWAY_TEAM',
    'SHOT_ACTION_TYPE',
    'SHOT_X_LOCATION',
    'SHOT_Y_LOCATION',

]

columns_to_scale = [
    'PLAYER_YEAR_START',
    'PLAYER_GAME_AGE',
    'PLAYER_HEIGHT', 
    'PLAYER_WEIGHT', 
    'PLAYER_BORN_YEAR',
    'PLAYER_EXP',
    'GAME_PERIOD',
    'GAME_PERIODE_SECOND_REMAINGING',
    'SHOT_DISTANCE',

]

categorical_columns = [
    'PLAYER_POS',
    'SHOT_ACTION_CATEGORY',
    'SHOT_TYPE',
    'SHOT_ZONE_BASIC',
    'SHOT_ZONE_AREA',
    'SHOT_ZONE_RANGE',

]

# dummies columns 
data_encoded = pd.get_dummies(data[categorical_columns], columns=categorical_columns)
data_encoded.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

data = pd.concat([data, data_encoded], axis=1)
data = data.drop(categorical_columns, axis=1)

# Drop columns
data = data.drop(columns_to_drop, axis=1)

# normelize columns 
scaler = StandardScaler()
data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])

# Save data
data.to_csv("../data/processed/data_preprocessed.csv", index=False)

data.head()
# Out:
#    PLAYER_YEAR_START  PLAYER_GAME_AGE  PLAYER_HEIGHT  PLAYER_WEIGHT  \
# 0          -1.788159         0.235575      -0.766211      -0.682981
# 1          -1.788159         0.235575      -0.766211      -0.682981
# 2          -1.788159         0.235575      -0.766211      -0.682981
# 3          -1.788159         0.235575      -0.766211      -0.682981
# 4          -1.788159         0.235575      -0.766211      -0.682981
#
#    PLAYER_BORN_YEAR  PLAYER_EXP  GAME_PERIOD  GAME_PERIODE_SECOND_REMAINGING  \
# 0         -1.140319    0.609749     1.336712                        1.595207
# 1         -1.140319    0.609749     1.336712                        1.088236
# 2         -1.140319    0.609749     1.336712                       -0.772253
# 3         -1.140319    0.609749     1.336712                       -1.164438
# 4         -1.140319    0.609749     1.336712                       -1.451403
#
#    SHOT_DISTANCE  SHOT_MADE_FLAG  ...  SHOT_ZONE_AREA_Center(C)  \
# 0       0.308400               1  ...                     False
# 1       0.205792               0  ...                     False
# 2      -0.204643               0  ...                     False
# 3      -0.717686               0  ...                      True
# 4       0.205792               0  ...                     False
#
#    SHOT_ZONE_AREA_Left_Side_Center(LC)  SHOT_ZONE_AREA_Left_Side(L)  \
# 0                                False                        False
# 1                                False                        False
# 2                                False                         True
# 3                                False                        False
# 4                                False                        False
#
#    SHOT_ZONE_AREA_Right_Side_Center(RC)  SHOT_ZONE_AREA_Right_Side(R)  \
# 0                                 False                          True
# 1                                 False                          True
# 2                                 False                         False
# 3                                 False                         False
# 4                                 False                          True
#
#    SHOT_ZONE_RANGE_16-24_ft.  SHOT_ZONE_RANGE_24+_ft.  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
#
#    SHOT_ZONE_RANGE_8-16_ft.  SHOT_ZONE_RANGE_Back_Court_Shot  \
# 0                      True                            False
# 1                      True                            False
# 2                      True                            False
# 3                     False                            False
# 4                      True                            False
#
#    SHOT_ZONE_RANGE_Less_Than_8_ft.
# 0                            False
# 1                            False
# 2                            False
# 3                             True
# 4                            False
#
# [5 rows x 53 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3986275 entries, 0 to 3986274
# Data columns (total 53 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   PLAYER_YEAR_START                      float64
#  1   PLAYER_GAME_AGE                        float64
#  2   PLAYER_HEIGHT                          float64
#  3   PLAYER_WEIGHT                          float64
#  4   PLAYER_BORN_YEAR                       float64
#  5   PLAYER_EXP                             float64
#  6   GAME_PERIOD                            float64
#  7   GAME_PERIODE_SECOND_REMAINGING         float64
#  8   SHOT_DISTANCE                          float64
#  9   SHOT_MADE_FLAG                         int64
#  10  PLAYER_POS_C                           bool
#  11  PLAYER_POS_C-PF                        bool
#  12  PLAYER_POS_C-SF                        bool
#  13  PLAYER_POS_PF                          bool
#  14  PLAYER_POS_PF-C                        bool
#  15  PLAYER_POS_PF-SF                       bool
#  16  PLAYER_POS_PG                          bool
#  17  PLAYER_POS_PG-SF                       bool
#  18  PLAYER_POS_PG-SG                       bool
#  19  PLAYER_POS_SF                          bool
#  20  PLAYER_POS_SF-PF                       bool
#  21  PLAYER_POS_SF-SG                       bool
#  22  PLAYER_POS_SG                          bool
#  23  PLAYER_POS_SG-PF                       bool
#  24  PLAYER_POS_SG-PG                       bool
#  25  PLAYER_POS_SG-SF                       bool
#  26  SHOT_ACTION_CATEGORY_Bank_Shot         bool
#  27  SHOT_ACTION_CATEGORY_Dunk_Shot         bool
#  28  SHOT_ACTION_CATEGORY_Hook_Shot         bool
#  29  SHOT_ACTION_CATEGORY_Jump_Shot         bool
#  30  SHOT_ACTION_CATEGORY_Layup_Shot        bool
#  31  SHOT_ACTION_CATEGORY_Other             bool
#  32  SHOT_ACTION_CATEGORY_Tip_Shot          bool
#  33  SHOT_TYPE_2PT_Field_Goal               bool
#  34  SHOT_TYPE_3PT_Field_Goal               bool
#  35  SHOT_ZONE_BASIC_Above_the_Break_3      bool
#  36  SHOT_ZONE_BASIC_Backcourt              bool
#  37  SHOT_ZONE_BASIC_In_The_Paint_(Non-RA)  bool
#  38  SHOT_ZONE_BASIC_Left_Corner_3          bool
#  39  SHOT_ZONE_BASIC_Mid-Range              bool
#  40  SHOT_ZONE_BASIC_Restricted_Area        bool
#  41  SHOT_ZONE_BASIC_Right_Corner_3         bool
#  42  SHOT_ZONE_AREA_Back_Court(BC)          bool
#  43  SHOT_ZONE_AREA_Center(C)               bool
#  44  SHOT_ZONE_AREA_Left_Side_Center(LC)    bool
#  45  SHOT_ZONE_AREA_Left_Side(L)            bool
#  46  SHOT_ZONE_AREA_Right_Side_Center(RC)   bool
#  47  SHOT_ZONE_AREA_Right_Side(R)           bool
#  48  SHOT_ZONE_RANGE_16-24_ft.              bool
#  49  SHOT_ZONE_RANGE_24+_ft.                bool
#  50  SHOT_ZONE_RANGE_8-16_ft.               bool
#  51  SHOT_ZONE_RANGE_Back_Court_Shot        bool
#  52  SHOT_ZONE_RANGE_Less_Than_8_ft.        bool
# dtypes: bool(43), float64(9), int64(1)
# memory usage: 467.6 MB
