# %%
import pandas as pd 
import joblib
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from shapash.explainer.smart_explainer import SmartExplainer

import shap

# %%
# Load the training and testing data
data_split = joblib.load('../data/processed/data_split.joblib')

# Extract split
X_train = data_split['X_train']
X_test = data_split['X_test']
y_train = data_split['y_train']
y_test = data_split['y_test']

# Charger le modèle depuis le fichier joblib
loaded_model_data = joblib.load('../models/decision_tree_model.joblib')
loaded_best_model = loaded_model_data['best_model']

# %%
# Explain the logistic regression model's predictions using SHAP values
explainer = shap.Explainer(loaded_best_model, X_train)
shap_values = explainer(X_test)

# %%
shap.summary_plot(shap_values, X_test, plot_type="bar", plot_size=(10, 5), show=False)
plt.show()

# %% [markdown]
# # Shapash

# %%
xpl = SmartExplainer(model=loaded_best_model)

# Remove the `model` argument from the compile() method call.
xpl.compile(
    x=X_test
)

app = xpl.run_app()
# Out:
# /Users/yoannfaure/anaconda3/envs/NBA_Inter/lib/python3.9/site-packages/shapash/webapp/smart_app.py:121: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# /Users/yoannfaure/anaconda3/envs/NBA_Inter/lib/python3.9/site-packages/shapash/webapp/utils/utils.py:41: FutureWarning:
#
# Index.is_numeric is deprecated. Use pandas.api.types.is_any_real_numeric_dtype instead
#
# INFO:root:Your Shapash application run on http://MacBook-Pro-de-Yoann.local:8050/
# INFO:root:Use the method .kill() to down your app.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://0.0.0.0:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
